# %%
# mean(Average)
age=[12,21,23,45,43,5,6,7]
import numpy as np
np.mean(age)
# Out:
# 20.25

# %%
import seaborn as sns
df=sns.load_dataset('tips')
print( "average:",np.mean(df['total_bill']))
df
# Out:
# average: 19.78594262295082
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
##median
np.median(age)
# Out:
# 16.5

# %%
#consider an outlier in the age
age=[12,21,23,45,43,5,6,7,500]
print(np.mean(age))
print(np.median(age))
#basically median is usee to mesure central tendency where the outlier is present
# Out:
# 73.55555555555556
# 21.0

# %%
#mode
from scipy import stats
stats.mode(age)
# Out:
# ModeResult(mode=5, count=1)

# %%
np.median(df['total_bill'])
# Out:
# 17.795

# %%
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
##measure of despersion
age=[12,21,23,45,43,5,6,7]
import numpy as np
variance=np.var(age)
std=np.std(age)
print(variance)
print(std)
# Out:
# 227.1875
# 15.07274029498286

# %%
#here wee can show the spread of the data by the use of kde
import seaborn as sns
sns.histplot(age,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd
data=[[10,12,13],[34,35,36],[32,43,21]]
data
# Out:
# [[10, 12, 13], [34, 35, 36], [32, 43, 21]]

# %%
df=pd.DataFrame(data,columns=["A","B","c"])
df
# Out:
#     A   B   c
# 0  10  12  13
# 1  34  35  36
# 2  32  43  21

# %%
#here wee can show variance of the individual column
df.var()
# Out:
# A    177.333333
# B    259.000000
# c    136.333333
# dtype: float64

# %%
#variance accoding to row
df.var(axis=1)
# Out:
# 0      2.333333
# 1      1.000000
# 2    121.000000
# dtype: float64

# %%
df.std()
# Out:
# A    13.316656
# B    16.093477
# c    11.676187
# dtype: float64

# %%
#Covatiance and corelation

# %%
import seaborn as sns
df=sns.load_dataset('healthexp')
df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
#covariance
df.cov()
# Out:
# <ipython-input-5-d6cb88869cc2>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#                          Year  Spending_USD  Life_Expectancy
# Year               201.098848  2.571883e+04        41.915454
# Spending_USD     25718.827373  4.817761e+06      4166.800912
# Life_Expectancy     41.915454  4.166801e+03        10.733902

# %%
#Pearson corellation coefficient
#in pearson corelation all value comes in [1-,1]
df.corr(method='pearson')
# Out:
# <ipython-input-8-5277f0fe72bf>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#                      Year  Spending_USD  Life_Expectancy
# Year             1.000000      0.826273         0.902175
# Spending_USD     0.826273      1.000000         0.579430
# Life_Expectancy  0.902175      0.579430         1.000000

# %%
#spearman corellation
df.corr(method='spearman')
# Out:
# <ipython-input-9-7ce6872d3497>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='spearman')
#                      Year  Spending_USD  Life_Expectancy
# Year             1.000000      0.931598         0.896117
# Spending_USD     0.931598      1.000000         0.747407
# Life_Expectancy  0.896117      0.747407         1.000000

# %%
df=sns.load_dataset('flights')
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
#bydefault pearson corellation will come
df.corr()
# Out:
# <ipython-input-11-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000
